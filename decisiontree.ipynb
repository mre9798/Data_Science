# %% [markdown]
# <a href="https://colab.research.google.com/github/mre9798/Data_science/blob/main/decisiontree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

ds=pd.read_csv('iris.csv')

x=ds.iloc[:,:4]
y=ds.iloc[:,-1]


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.25)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)
print("Accuracy :",accuracy_score(y_test,y_pred))

from sklearn import tree
tree.plot_tree(clf)
# Out:
# Accuracy : 0.9736842105263158
# [Text(133.92000000000002, 195.696, 'X[3] <= 0.8\ngini = 0.667\nsamples = 112\nvalue = [38, 37, 37]'),
#  Text(100.44000000000001, 152.208, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(167.40000000000003, 152.208, 'X[2] <= 4.95\ngini = 0.5\nsamples = 74\nvalue = [0, 37, 37]'),
#  Text(66.96000000000001, 108.72, 'X[3] <= 1.65\ngini = 0.18\nsamples = 40\nvalue = [0, 36, 4]'),
#  Text(33.480000000000004, 65.232, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(100.44000000000001, 65.232, 'X[1] <= 3.1\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(66.96000000000001, 21.744, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(133.92000000000002, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(267.84000000000003, 108.72, 'X[2] <= 5.05\ngini = 0.057\nsamples = 34\nvalue = [0, 1, 33]'),
#  Text(234.36, 65.232, 'X[0] <= 6.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(200.88000000000002, 21.744, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(267.84000000000003, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(301.32000000000005, 65.232, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

ds=pd.read_csv('wine.csv')

ds.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0     1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1     1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2     1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3     1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4     1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
#
# [5 rows x 14 columns]

# %%
x=ds.iloc[:,1:]
y=ds.iloc[:,:1]
x
# Out:
#      Alcohol  Malic.acid   Ash   Acl  ...  Color.int   Hue    OD  Proline
# 0      14.23        1.71  2.43  15.6  ...       5.64  1.04  3.92     1065
# 1      13.20        1.78  2.14  11.2  ...       4.38  1.05  3.40     1050
# 2      13.16        2.36  2.67  18.6  ...       5.68  1.03  3.17     1185
# 3      14.37        1.95  2.50  16.8  ...       7.80  0.86  3.45     1480
# 4      13.24        2.59  2.87  21.0  ...       4.32  1.04  2.93      735
# ..       ...         ...   ...   ...  ...        ...   ...   ...      ...
# 173    13.71        5.65  2.45  20.5  ...       7.70  0.64  1.74      740
# 174    13.40        3.91  2.48  23.0  ...       7.30  0.70  1.56      750
# 175    13.27        4.28  2.26  20.0  ...      10.20  0.59  1.56      835
# 176    13.17        2.59  2.37  20.0  ...       9.30  0.60  1.62      840
# 177    14.13        4.10  2.74  24.5  ...       9.20  0.61  1.60      560
#
# [178 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.25)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)
print("Accuracy :",accuracy_score(y_test,y_pred))

from sklearn import tree
tree.plot_tree(clf)
# Out:
# Accuracy : 0.8444444444444444
# [Text(167.4, 199.32, 'X[12] <= 760.0\ngini = 0.658\nsamples = 133\nvalue = [49, 50, 34]'),
#  Text(83.7, 163.07999999999998, 'X[9] <= 4.8\ngini = 0.502\nsamples = 81\nvalue = [2, 48, 31]'),
#  Text(41.85, 126.83999999999999, 'X[0] <= 12.815\ngini = 0.206\nsamples = 53\nvalue = [2, 47, 4]'),
#  Text(20.925, 90.6, 'gini = 0.0\nsamples = 43\nvalue = [0, 43, 0]'),
#  Text(62.775000000000006, 90.6, 'X[6] <= 1.275\ngini = 0.64\nsamples = 10\nvalue = [2, 4, 4]'),
#  Text(41.85, 54.359999999999985, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(83.7, 54.359999999999985, 'X[5] <= 2.63\ngini = 0.444\nsamples = 6\nvalue = [2, 4, 0]'),
#  Text(62.775000000000006, 18.119999999999976, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(104.625, 18.119999999999976, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(125.55000000000001, 126.83999999999999, 'X[3] <= 17.65\ngini = 0.069\nsamples = 28\nvalue = [0, 1, 27]'),
#  Text(104.625, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(146.475, 90.6, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 27]'),
#  Text(251.10000000000002, 163.07999999999998, 'X[6] <= 2.165\ngini = 0.178\nsamples = 52\nvalue = [47, 2, 3]'),
#  Text(209.25, 126.83999999999999, 'X[12] <= 883.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(188.32500000000002, 90.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(230.175, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(292.95, 126.83999999999999, 'X[4] <= 135.5\ngini = 0.041\nsamples = 48\nvalue = [47, 1, 0]'),
#  Text(272.02500000000003, 90.6, 'gini = 0.0\nsamples = 47\nvalue = [47, 0, 0]'),
#  Text(313.875, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]')]
